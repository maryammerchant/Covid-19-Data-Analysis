# %% [markdown]
# <a href="https://colab.research.google.com/github/maryammerchant/Covid-19-Data-Analysis/blob/main/covid_19_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Covid Analysis Project

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-258e74b1-0f31-4c82-a08f-c2e8557295f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-258e74b1-0f31-4c82-a08f-c2e8557295f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving owid-covid-data.csv to owid-covid-data.csv

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent  ... excess_mortality excess_mortality_cumulative_per_million
# 0      AFG      Asia  ...              NaN                                     NaN
# 1      AFG      Asia  ...              NaN                                     NaN
# 2      AFG      Asia  ...              NaN                                     NaN
# 3      AFG      Asia  ...              NaN                                     NaN
# 4      AFG      Asia  ...              NaN                                     NaN
#
# [5 rows x 67 columns]

# %%
df
# Out:
#        ISO_code  ... excess_mortality_cumulative_per_million
# 0           AFG  ...                                     NaN
# 1           AFG  ...                                     NaN
# 2           AFG  ...                                     NaN
# 3           AFG  ...                                     NaN
# 4           AFG  ...                                     NaN
# ...         ...  ...                                     ...
# 155134      ZWE  ...                                     NaN
# 155135      ZWE  ...                                     NaN
# 155136      ZWE  ...                                     NaN
# 155137      ZWE  ...                                     NaN
# 155138      ZWE  ...                                     NaN
#
# [155139 rows x 64 columns]

# %%
df1 = df[df['total_cases']>100000000]

# %%
df1
# Out:
#         iso_code  ... excess_mortality_cumulative_per_million
# 46753   OWID_EUR  ...                                     NaN
# 46754   OWID_EUR  ...                                     NaN
# 46755   OWID_EUR  ...                                     NaN
# 46756   OWID_EUR  ...                                     NaN
# 46757   OWID_EUR  ...                                     NaN
# ...          ...  ...                                     ...
# 153149  OWID_WRL  ...                                     NaN
# 153150  OWID_WRL  ...                                     NaN
# 153151  OWID_WRL  ...                                     NaN
# 153152  OWID_WRL  ...                                     NaN
# 153153  OWID_WRL  ...                                     NaN
#
# [464 rows x 67 columns]

# %%
df.drop(['new_cases_smoothed'],axis=1,inplace=True)

# %%
df
# Out:
#        iso_code  ... excess_mortality_cumulative_per_million
# 0           AFG  ...                                     NaN
# 1           AFG  ...                                     NaN
# 2           AFG  ...                                     NaN
# 3           AFG  ...                                     NaN
# 4           AFG  ...                                     NaN
# ...         ...  ...                                     ...
# 155134      ZWE  ...                                     NaN
# 155135      ZWE  ...                                     NaN
# 155136      ZWE  ...                                     NaN
# 155137      ZWE  ...                                     NaN
# 155138      ZWE  ...                                     NaN
#
# [155139 rows x 66 columns]

# %%
df.drop(['new_deaths_smoothed','new_deaths_smoothed','new_cases_per_million'],axis=1,inplace=True)

# %%
df
# Out:
#        iso_code  ... excess_mortality_cumulative_per_million
# 0           AFG  ...                                     NaN
# 1           AFG  ...                                     NaN
# 2           AFG  ...                                     NaN
# 3           AFG  ...                                     NaN
# 4           AFG  ...                                     NaN
# ...         ...  ...                                     ...
# 155134      ZWE  ...                                     NaN
# 155135      ZWE  ...                                     NaN
# 155136      ZWE  ...                                     NaN
# 155137      ZWE  ...                                     NaN
# 155138      ZWE  ...                                     NaN
#
# [155139 rows x 64 columns]

# %%
df.rename(columns={'date': 'Date','location':'Country','continent': 'Continent','iso_code':'ISO_code'},inplace=True)

# %%
df
# Out:
#        ISO_code  ... excess_mortality_cumulative_per_million
# 0           AFG  ...                                     NaN
# 1           AFG  ...                                     NaN
# 2           AFG  ...                                     NaN
# 3           AFG  ...                                     NaN
# 4           AFG  ...                                     NaN
# ...         ...  ...                                     ...
# 155134      ZWE  ...                                     NaN
# 155135      ZWE  ...                                     NaN
# 155136      ZWE  ...                                     NaN
# 155137      ZWE  ...                                     NaN
# 155138      ZWE  ...                                     NaN
#
# [155139 rows x 64 columns]

# %%
imputer = SimpleImputer(strategy='constant')
df2 = pd.DataFrame(imputer.fit_transform(df),columns=df.columns)

# %%
df3 = df2.groupby(['Date','Country',])[['Date','Country','total_cases','total_deaths','total_vaccinations']].sum().reset_index()

# %%
df3
# Out:
#               Date            Country  ...   total_deaths total_vaccinations
# 0       2020-01-01          Argentina  ...  missing_value      missing_value
# 1       2020-01-01             Mexico  ...  missing_value      missing_value
# 2       2020-01-01               Peru  ...  missing_value      missing_value
# 3       2020-01-02          Argentina  ...  missing_value      missing_value
# 4       2020-01-02             Mexico  ...  missing_value      missing_value
# ...            ...                ...  ...            ...                ...
# 155134  2022-01-16  Wallis and Futuna  ...              7      missing_value
# 155135  2022-01-16              World  ...    5.53957e+06        9.67623e+09
# 155136  2022-01-16              Yemen  ...           1990      missing_value
# 155137  2022-01-16             Zambia  ...           3860      missing_value
# 155138  2022-01-16           Zimbabwe  ...           5247        7.43848e+06
#
# [155139 rows x 5 columns]

# %%
df3['total_cases'].replace({'missing_value': 0}, inplace=True)

# %%
df3
# Out:
#               Date            Country  ...   total_deaths total_vaccinations
# 0       2020-01-01          Argentina  ...  missing_value      missing_value
# 1       2020-01-01             Mexico  ...  missing_value      missing_value
# 2       2020-01-01               Peru  ...  missing_value      missing_value
# 3       2020-01-02          Argentina  ...  missing_value      missing_value
# 4       2020-01-02             Mexico  ...  missing_value      missing_value
# ...            ...                ...  ...            ...                ...
# 155134  2022-01-16  Wallis and Futuna  ...              7      missing_value
# 155135  2022-01-16              World  ...    5.53957e+06        9.67623e+09
# 155136  2022-01-16              Yemen  ...           1990      missing_value
# 155137  2022-01-16             Zambia  ...           3860      missing_value
# 155138  2022-01-16           Zimbabwe  ...           5247        7.43848e+06
#
# [155139 rows x 5 columns]

# %%
df3['total_deaths'].replace({'missing_value':0},inplace=True)

# %%
df3
# Out:
#               Date            Country  ...  total_deaths  total_vaccinations
# 0       2020-01-01          Argentina  ...           0.0        0.000000e+00
# 1       2020-01-01             Mexico  ...           0.0        0.000000e+00
# 2       2020-01-01               Peru  ...           0.0        0.000000e+00
# 3       2020-01-02          Argentina  ...           0.0        0.000000e+00
# 4       2020-01-02             Mexico  ...           0.0        0.000000e+00
# ...            ...                ...  ...           ...                 ...
# 155134  2022-01-16  Wallis and Futuna  ...           7.0        0.000000e+00
# 155135  2022-01-16              World  ...     5539572.0        9.676232e+09
# 155136  2022-01-16              Yemen  ...        1990.0        0.000000e+00
# 155137  2022-01-16             Zambia  ...        3860.0        0.000000e+00
# 155138  2022-01-16           Zimbabwe  ...        5247.0        7.438485e+06
#
# [155139 rows x 5 columns]

# %%
countries = df3['Country'].unique()
len(countries)
# Out:
# 238

# %%
df4 = df3[df3['total_deaths']>1000000]

# %%
countries = df4['Country'].unique()
len(countries)
# Out:
# 8

# %%
for idx in range(0,len(countries)):
  C = df4[df4['Country']==countries[idx]].reset_index()
  plt.scatter(np.arange(0,len(C)),C['total_cases'],color="blue",label="total_cases")
  plt.scatter(np.arange(0,len(C)),C['total_deaths'],color="red",label="total_deaths")
  plt.scatter(np.arange(0,len(C)),C['total_vaccinations'],color="green",label="total_vaccinations")
  plt.title(countries[idx])
  plt.xlabel("Number of days since first suspect")
  plt.ylabel("Number of cases")
  plt.legend()
  plt.show()

# %%
df5 = df4.groupby(['Country'])[['Country','total_cases','total_deaths']].sum().reset_index()

# %%
C = df5
plt.scatter(np.arange(0,len(C)),C['total_cases'],color="blue",label="total_cases")
plt.scatter(np.arange(0,len(C)),C['total_deaths'],color="red",label="total_deaths")
plt.title("World")
plt.xlabel("Number of days since first suspect")
plt.ylabel("Number of cases")
plt.legend()
plt.show()

# %%
date = df4['Date'].unique()
len(date)
# Out:
# 486

# %%
df6 = df4.groupby(['Date'])[['Date','total_cases','total_deaths']].sum().reset_index()

# %%
C = df6
plt.scatter(np.arange(0,len(C)),C['total_cases'],color="blue",label="total_cases")
plt.scatter(np.arange(0,len(C)),C['total_deaths'],color="red",label="total_deaths")
plt.title("World")
plt.xlabel("Number of days since first suspect")
plt.ylabel("Number of cases")
plt.legend()
plt.show()
